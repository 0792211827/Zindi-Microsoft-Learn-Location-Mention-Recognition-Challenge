# %% [markdown]
# # Microsoft Learn Location Mention Recognition Challenge
#
#
# ## Problem statement
# During disasters, timely identification of critical information such as medical needs, shelter requirements, and reports of trapped individuals is essential for effective response. However, the usefulness of microblogging posts, such as those on X (formerly Twitter), is limited when they lack precise geotagging. While exact GPS data is often scarce, many posts include place names or street names (toponyms) that can be valuable for estimating locations. Due to the high volume of such posts, manual extraction of these location cues is impractical. This challenge aims to develop automated systems for Location Mention Recognition (LMR) in microblogging posts, enabling authorities to swiftly locate and respond to critical needs during emergencies.

# %% [markdown]
# ### Data collection
# The data from this challenge was provide by Zindi Africa.

# %%
 # Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
# loading the data 
train = pd.read_csv('Train_1.csv')
test = pd.read_csv('Test_microsoft.csv')
submission = pd.read_csv('SampleSubmission_microsoft.csv')

# %%
print(train.shape,test.shape,submission.shape)
# Out:
# (73072, 3) (2942, 2) (2942, 2)

# %%
train.head()
# Out:
#                  tweet_id                                               text  \
# 0  ID_1001136212718088192                                                NaN
# 1  ID_1001136696589631488  Flash floods struck a Maryland city on Sunday,...
# 2  ID_1001136950345109504  State of emergency declared for Maryland flood...
# 3  ID_1001137334056833024  Other parts of Maryland also saw significant d...
# 4  ID_1001138374923579392  Catastrophic Flooding Slams Ellicott City, Mar...
#
#                  location
# 0            EllicottCity
# 1                Maryland
# 2                Maryland
# 3      Baltimore Maryland
# 4  Ellicott City Maryland

# %%
test.head()
# Out:
#                  tweet_id                                               text
# 0  ID_1001154804658286592  What is happening to the infrastructure in New...
# 1  ID_1001155505459486720  SOLDER MISSING IN FLOOD.. PRAY FOR EDDISON HER...
# 2  ID_1001155756371136512  RT @TIME: Police searching for missing person ...
# 3  ID_1001159445194399744  Flash Flood Tears Through Maryland Town For Se...
# 4  ID_1001164907587538944  Ellicott City #FLOODING Pictures: Maryland Gov...

# %%
submission.head()
# Out:
#                  tweet_id  location
# 0  ID_1001154804658286592       NaN
# 1  ID_1001155505459486720       NaN
# 2  ID_1001155756371136512       NaN
# 3  ID_1001159445194399744       NaN
# 4  ID_1001164907587538944       NaN

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73072 entries, 0 to 73071
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  73072 non-null  object
#  1   text      16448 non-null  object
#  2   location  43460 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2942 entries, 0 to 2941
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2942 non-null   object
#  1   text      2942 non-null   object
# dtypes: object(2)
# memory usage: 46.1+ KB

# %% [markdown]
# The data has alot of missing values.

# %%
train.isnull().sum()
# Out:
# tweet_id        0
# text        56624
# location    29612
# dtype: int64

# %% [markdown]
# Most of the data in the train data is missing

# %%
test.isnull().sum()
# Out:
# tweet_id    0
# text        0
# dtype: int64

# %% [markdown]
# No missing values in the test dataset

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 0

# %%
# dropping the missing value 
train = train.dropna()

# %%
train.isnull().sum()
# Out:
# tweet_id    0
# text        0
# location    0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11849 entries, 1 to 73071
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  11849 non-null  object
#  1   text      11849 non-null  object
#  2   location  11849 non-null  object
# dtypes: object(3)
# memory usage: 370.3+ KB

# %%
train.apply(lambda x:len(x.unique()))
# Out:
# tweet_id    11849
# text        11849
# location     3448
# dtype: int64

# %%
train['location'].value_counts()
# Out:
# Mexico                               582
# California                           544
# Ecuador                              539
# Nebraska                             495
# Haiti                                424
#                                     ...
# Florida Mexico Nebraska Texas          1
# Chimanimani- Zimbabwe                  1
# Mozambique South African Zimbabwe      1
# Manicaland Mutare                      1
# Israels Mexico City Thailand           1
# Name: location, Length: 3448, dtype: int64

# %% [markdown]
# ## Text cleaning

# %%
import nltk
import string
import re
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
stopword = set(stopwords.words('english'))
stemmer = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()
from textblob import TextBlob
from wordcloud import WordCloud
from matplotlib.ticker import MaxNLocator
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from wordcloud import WordCloud, STOPWORDS
from collections import Counter, defaultdict
from PIL import Image

# %%
#CONCATENATING BOTH THE TEST AND TRAIN FOR EASY DATA MANIPULATON
ntrain = train.shape[0]
ntest = test.shape[0]
data = pd.concat((train, test)).reset_index(drop=True)
data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 3 columns]

# %%
# #storing it into a data frame for easy manipulation
# content = pd.DataFrame(content, columns=['text'])

# %%
# Removing Digits
data['cleaned_text'] = data['text'].apply(lambda d: re.sub(r'\d','', d) if isinstance(d, str) else d)
data['cleaned_location'] = data['location'].apply(lambda d: re.sub(r'\d','', d) if isinstance(d, str) else d)

# %%
# Removing all commas
data['cleaned_text'] = data['cleaned_text'].apply(lambda v: re.sub(',', '', v) if isinstance(v, str) else v)
data['cleaned_location'] = data['cleaned_location'].apply(lambda v: re.sub(',', '', v) if isinstance(v, str) else v)

# %%
#a function to remove emojis
def remove_emoji(text):
    if not isinstance(text, str):
        return text 
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols & Pictographs
        "\U0001F680-\U0001F6FF"  # Transport & Map Symbols
        "\U0001F700-\U0001F77F"  # Alchemical Symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"  # Enclosed Characters
        "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', text)

data['cleaned_text'] = data['cleaned_text'].apply(remove_emoji)
data['cleaned_location'] = data['cleaned_location'].apply(remove_emoji)
data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      Flash floods struck a Maryland city on Sunday ...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City Mary...
# 4      WATCH:  missing after flash #FLOODING devastat...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $K To Mexico...
#
#              cleaned_location
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %%
#remove HTML tags
def remove_html(text):
    if not isinstance(text, str):
        return text
    html_pattern = re.compile(r'<.*?>')
    return html_pattern.sub(r'', text)

data['cleaned_text'] = data['cleaned_text'].apply(remove_html)
data['cleaned_location'] = data['cleaned_location'].apply(remove_html)
data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      Flash floods struck a Maryland city on Sunday ...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City Mary...
# 4      WATCH:  missing after flash #FLOODING devastat...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $K To Mexico...
#
#              cleaned_location
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %%
# remove URLs
def remove_URL(text):
    if not isinstance(text, str):
        return text
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

data['cleaned_text'] = data['cleaned_text'].apply(remove_URL)
data['cleaned_location'] = data['cleaned_location'].apply(remove_URL)
data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      Flash floods struck a Maryland city on Sunday ...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City Mary...
# 4      WATCH:  missing after flash #FLOODING devastat...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $K To Mexico...
#
#              cleaned_location
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %% [markdown]
# ## Data Preparation, Tokenization, Stopwords Removal and Stemming

# %% [markdown]
# #### lower casing the text

# %%
#converting text into lowercase
data['cleaned_text'] = data['cleaned_text'].str.lower()
data['cleaned_location'] = data['cleaned_location'].str.lower()
data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      flash floods struck a maryland city on sunday ...
# 1      state of emergency declared for maryland flood...
# 2      other parts of maryland also saw significant d...
# 3      catastrophic flooding slams ellicott city mary...
# 4      watch:  missing after flash #flooding devastat...
# ...                                                  ...
# 14786  @purinacatchow he wants to donate some food to...
# 14787  @hannahstocking i live the mexico earthquake a...
# 14788  rt @globalcalgary: watch: national taco day in...
# 14789  oaxaca & chiapas – mexico’s poorest states – h...
# 14790  rt @cbssf: carlos santana donates $k to mexico...
#
#              cleaned_location
# 0                    maryland
# 1                    maryland
# 2          baltimore maryland
# 3      ellicott city maryland
# 4      ellicott city maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %%
#filter out words that are shorter than or equal to two characters.
data['cleaned_text'] = data['cleaned_text'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 2]))

# %%
 data.sample(10)
# Out:
#                      tweet_id  \
# 2054   ID_1040550528386834432
# 2570   ID_1062051934826246144
# 7678    ID_783488305128144896
# 12428  ID_1061150344103653376
# 7811    ID_783675792349724672
# 9875    ID_907942430992883712
# 3427   ID_1108352212609232896
# 14089   ID_877124359478927360
# 3451   ID_1108432465503367168
# 4686   ID_1116623360148983808
#
#                                                     text         location  \
# 2054   Hurricane Florence has knocked out power to mo...   North Carolina
# 2570   Death toll hits 31, hundreds missing in record...  Cali California
# 7678   You can help provide relief in #Haiti for thos...            Haiti
# 12428  At least 9 die in California wildfires as tens...              NaN
# 7811   Hurricane Matthew moves into Bahamas after bat...    Bahamas Haiti
# 9875   Just when you thought it was safe.San Diego qu...        San Diego
# 3427   Now we have a President who wants to oversee d...      Zimbabweans
# 14089  Donation from #Bangladesh to assist the recent...              NaN
# 3451   Dear World Leaders: Please make sure all donat...         Zimbabwe
# 4686   Farmers in some of hardest-hit areas of #Mozam...       Mozambique
#
#                                             cleaned_text cleaned_location
# 2054   hurricane florence has knocked out power more ...   north carolina
# 2570   death toll hits hundreds missing record-breaki...  cali california
# 7678   you can help provide relief #haiti for those a...            haiti
# 12428  least die california wildfires tens thousands ...              NaN
# 7811   hurricane matthew moves into bahamas after bat...    bahamas haiti
# 9875   just when you thought was safe.san diego quake...        san diego
# 3427   now have president who wants oversee distribut...      zimbabweans
# 14089  donation from #bangladesh assist the recent #f...              NaN
# 3451   dear world leaders: please make sure all donat...         zimbabwe
# 4686   farmers some hardest-hit areas #mozambique rec...       mozambique

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punctuation = string.punctuation + "’‘"
# Apply the function to remove all punctuation characters, ignoring non-string values
data['cleaned_text'] = data['cleaned_text'].apply(lambda doc: "".join([x for x in doc if x not in punctuation]) if isinstance(doc, str) else doc)
data['cleaned_location'] = data['cleaned_location'].apply(lambda doc: "".join([x for x in doc if x not in punctuation]) if isinstance(doc, str) else doc)
data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      flash floods struck maryland city sunday washi...
# 1      state emergency declared for maryland flooding...
# 2      other parts maryland also saw significant dama...
# 3      catastrophic flooding slams ellicott city mary...
# 4      watch missing after flash flooding devastates ...
# ...                                                  ...
# 14786  purinacatchow wants donate some food homeless ...
# 14787  hannahstocking live the mexico earthquake and ...
# 14788  globalcalgary watch national taco day calgary ...
# 14789  oaxaca chiapas mexicos poorest states harshest...
# 14790  cbssf carlos santana donates mexico earthquake...
#
#              cleaned_location
# 0                    maryland
# 1                    maryland
# 2          baltimore maryland
# 3      ellicott city maryland
# 4      ellicott city maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %% [markdown]
# #### Removing Stop words

# %%
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'himself', 'here', 'can', 'who', 'where', 'each', 'hers', 'them', 'y', "needn't", "wouldn't", 'but', 'in', 'once', 'other', 'so', 'a', 'his', 'shouldn', 'should', 'was', 'below', 'under', 'isn', 'over', 'just', 'again', 'has', "she's", 'they', 'about', 'how', 'most', 'd', 'when', 'after', "you've", 'doesn', 'are', 'am', 'be', 'against', 'have', 'these', "that'll", 'such', 'won', 'themselves', 'had', 'needn', 'than', 'out', 'at', "should've", 'ours', "doesn't", 'nor', 'itself', "won't", 'to', 'haven', 'he', 'does', 'any', 'not', 'ma', 'because', 'aren', 'off', 'hasn', 'i', 'herself', 'that', 'me', 'hadn', 'couldn', 'there', 'same', 'ourselves', 'if', "aren't", "couldn't", 'your', 'is', 'were', 'no', "haven't", 'into', 'yours', 'been', 'very', 'she', "it's", "wasn't", 'did', 'while', "weren't", 'being', 'before', 'having', 'why', 'wasn', 'now', 'their', 'm', "hadn't", 'the', 'you', 'then', 'and', 'during', 'doing', 'of', 'will', 'it', 'up', 'from', 'her', 'on', 'what', 'do', 'my', 't', 'myself', "you'll", 'an', 'few', 'further', 'which', 'with', 'whom', 'down', 'weren', 'both', 'until', 'we', "shan't", 'this', 'him', 'some', "shouldn't", "mightn't", 'o', 'more', 'theirs', 'mustn', 'our', 're', 'yourselves', "isn't", 'by', 'as', 've', 'above', "hasn't", 's', "mustn't", "you'd", 'own', 'll', 'wouldn', 'those', 'only', 'shan', 'ain', 'too', 'through', 'yourself', 'or', 'for', 'mightn', 'didn', 'all', "you're", "don't", "didn't", 'its', 'don', 'between'}

# %%
data['cleaned_text'] = data['cleaned_text'].apply(lambda y: " ".join([j for j in y.split() if j not in stop_words]))
data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      flash floods struck maryland city sunday washi...
# 1      state emergency declared maryland flooding via...
# 2      parts maryland also saw significant damage sun...
# 3      catastrophic flooding slams ellicott city mary...
# 4      watch missing flash flooding devastates ellico...
# ...                                                  ...
# 14786  purinacatchow wants donate food homeless cats ...
# 14787  hannahstocking live mexico earthquake house da...
# 14788  globalcalgary watch national taco day calgary ...
# 14789  oaxaca chiapas mexicos poorest states harshest...
# 14790  cbssf carlos santana donates mexico earthquake...
#
#              cleaned_location
# 0                    maryland
# 1                    maryland
# 2          baltimore maryland
# 3      ellicott city maryland
# 4      ellicott city maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %% [markdown]
# ### Tokenization

# %%
data['cleaned_text'] = data['cleaned_text'].apply(word_tokenize)
data.sample(10)
# Out:
#                      tweet_id  \
# 5733   ID_1176600565914263552
# 11661   ID_914218787892842496
# 5822   ID_1176848695507243008
# 9018    ID_872194467725553664
# 4722   ID_1167494999732346880
# 4090   ID_1111267612682534912
# 9691    ID_906209380235870208
# 955    ID_1025921960788860928
# 8596    ID_798030484466855936
# 2888   ID_1064517751912521728
#
#                                                     text  \
# 5733   @SalmanSoz @PMOIndia When the siege is lifted ...
# 11661  Fantastic work, MarcoFabian_10! ὄF The eintrac...
# 5822   Pakistan Army chief General Bajwa visits areas...
# 9018   RT @reliefweb: .@UNmigration to assist #SriLan...
# 4722   Red Cross deploys TN volunteers to GA, FL to p...
# 4090   Infogressive is still donating 25% of their se...
# 9691   Florida governor Rick Scott warns all resident...
# 955    Fire Risk warning Aug 4-5: Attica, Aegean isla...
# 8596   ὢB sad #NZeq #NewZealand #earthquake: Two conf...
# 2888   @DavidKelsey3 @Alyssa_Milano Im willing to bet...
#
#                            location  \
# 5733                        Kashmir
# 11661                       Mexicos
# 5822                       Pakistan
# 9018                       SriLanka
# 4722                       FL GA TN
# 4090                      Nebraskas
# 9691                        Florida
# 955    Aegean islands Attica Greece
# 8596                     NewZealand
# 2888             California Georgia
#
#                                             cleaned_text  \
# 5733   [salmansoz, pmoindia, siege, lifted, kashmir, ...
# 11661  [fantastic, work, marcofabian, eintrachteng, p...
# 5822   [pakistan, army, chief, general, bajwa, visits...
# 9018   [reliefweb, unmigration, assist, srilanka, flo...
# 4722   [red, cross, deploys, volunteers, prepare, hur...
# 4090   [infogressive, still, donating, service, fees,...
# 9691   [florida, governor, rick, scott, warns, reside...
# 955    [fire, risk, warning, aug, attica, aegean, isl...
# 8596   [sad, nzeq, newzealand, earthquake, two, confi...
# 2888   [davidkelsey, alyssamilano, willing, bet, geor...
#
#                    cleaned_location
# 5733                        kashmir
# 11661                       mexicos
# 5822                       pakistan
# 9018                       srilanka
# 4722                       fl ga tn
# 4090                      nebraskas
# 9691                        florida
# 955    aegean islands attica greece
# 8596                     newzealand
# 2888             california georgia

# %% [markdown]
# ### Part of speech tags

# %%
data['cleaned_text'] = data['cleaned_text'].apply(nltk.tag.pos_tag)
data.head()
# Out:
#                  tweet_id                                               text  \
# 0  ID_1001136696589631488  Flash floods struck a Maryland city on Sunday,...
# 1  ID_1001136950345109504  State of emergency declared for Maryland flood...
# 2  ID_1001137334056833024  Other parts of Maryland also saw significant d...
# 3  ID_1001138374923579392  Catastrophic Flooding Slams Ellicott City, Mar...
# 4  ID_1001138377717157888  WATCH: 1 missing after flash #FLOODING devasta...
#
#                  location                                       cleaned_text  \
# 0                Maryland  [(flash, JJ), (floods, NNS), (struck, VBD), (m...
# 1                Maryland  [(state, NN), (emergency, NN), (declared, VBD)...
# 2      Baltimore Maryland  [(parts, NNS), (maryland, NN), (also, RB), (sa...
# 3  Ellicott City Maryland  [(catastrophic, JJ), (flooding, VBG), (slams, ...
# 4  Ellicott City Maryland  [(watch, NN), (missing, VBG), (flash, NN), (fl...
#
#          cleaned_location
# 0                maryland
# 1                maryland
# 2      baltimore maryland
# 3  ellicott city maryland
# 4  ellicott city maryland

# %% [markdown]
# ### Convert part of speech to wordnet format

# %%
# Converting part of speeches to wordnet format.

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

data['cleaned_text'] = data['cleaned_text'].apply(
    lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      [(flash, a), (floods, n), (struck, v), (maryla...
# 1      [(state, n), (emergency, n), (declared, v), (m...
# 2      [(parts, n), (maryland, n), (also, r), (saw, v...
# 3      [(catastrophic, a), (flooding, v), (slams, a),...
# 4      [(watch, n), (missing, v), (flash, n), (floodi...
# ...                                                  ...
# 14786  [(purinacatchow, n), (wants, v), (donate, a), ...
# 14787  [(hannahstocking, v), (live, a), (mexico, n), ...
# 14788  [(globalcalgary, a), (watch, n), (national, a)...
# 14789  [(oaxaca, a), (chiapas, n), (mexicos, n), (poo...
# 14790  [(cbssf, n), (carlos, n), (santana, n), (donat...
#
#              cleaned_location
# 0                    maryland
# 1                    maryland
# 2          baltimore maryland
# 3      ellicott city maryland
# 4      ellicott city maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %%
# Applying word lemmatizer(converts the word to a meaningful base form. For example, "running" becomes "run", "better" becomes "good" if part-of-speech is considered.)


wnl = WordNetLemmatizer()

data['cleaned_text'] = data['cleaned_text'].apply(
    lambda x: [wnl.lemmatize(word, tag) for word, tag in x])

data
# Out:
#                      tweet_id  \
# 0      ID_1001136696589631488
# 1      ID_1001136950345109504
# 2      ID_1001137334056833024
# 3      ID_1001138374923579392
# 4      ID_1001138377717157888
# ...                       ...
# 14786   ID_915017703055749120
# 14787   ID_915026957758328832
# 14788   ID_915253441726889984
# 14789   ID_915971980859400192
# 14790   ID_916099144116191232
#
#                                                     text  \
# 0      Flash floods struck a Maryland city on Sunday,...
# 1      State of emergency declared for Maryland flood...
# 2      Other parts of Maryland also saw significant d...
# 3      Catastrophic Flooding Slams Ellicott City, Mar...
# 4      WATCH: 1 missing after flash #FLOODING devasta...
# ...                                                  ...
# 14786  @PurinaCatChow he wants to donate some food to...
# 14787  @HannahStocking I live the Mexico earthquake a...
# 14788  RT @GlobalCalgary: WATCH: National Taco Day in...
# 14789  Oaxaca & Chiapas – Mexico’s poorest states – h...
# 14790  RT @CBSSF: Carlos Santana Donates $100K To Mex...
#
#                      location  \
# 0                    Maryland
# 1                    Maryland
# 2          Baltimore Maryland
# 3      Ellicott City Maryland
# 4      Ellicott City Maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
#                                             cleaned_text  \
# 0      [flash, flood, strike, maryland, city, sunday,...
# 1      [state, emergency, declare, maryland, flood, v...
# 2      [part, maryland, also, saw, significant, damag...
# 3      [catastrophic, flood, slams, ellicott, city, m...
# 4      [watch, miss, flash, flooding, devastate, elli...
# ...                                                  ...
# 14786  [purinacatchow, want, donate, food, homeless, ...
# 14787  [hannahstocking, live, mexico, earthquake, hou...
# 14788  [globalcalgary, watch, national, taco, day, ca...
# 14789  [oaxaca, chiapas, mexico, poor, state, harshes...
# 14790  [cbssf, carlos, santana, donate, mexico, earth...
#
#              cleaned_location
# 0                    maryland
# 1                    maryland
# 2          baltimore maryland
# 3      ellicott city maryland
# 4      ellicott city maryland
# ...                       ...
# 14786                     NaN
# 14787                     NaN
# 14788                     NaN
# 14789                     NaN
# 14790                     NaN
#
# [14791 rows x 5 columns]

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Most common unigrams

# %%
from collections import Counter
import matplotlib.cm as cm

# Flatten the list of words in the entire dataset
all_words = [word for tokens in data['cleaned_text'] for word in tokens]

# Count the frequency of each word
word_freq = Counter(all_words)

# Get the 20 most common unigrams
common_words = word_freq.most_common(20)

# Split the words and their counts for plotting
words, counts = zip(*common_words)

# Define a colormap
colors = cm.viridis_r([i/20 for i in range(20)])

# Plotting the most common unigrams 
plt.figure(figsize=(12, 8))
plt.barh(words, counts, color=colors)
plt.gca().invert_yaxis()
plt.xlabel('Frequency')
plt.ylabel('Unigrams')
plt.title('Top 20 Most Common Unigrams')
plt.show()

# %% [markdown]
# #### Most common Bigrams

# %%
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from nltk import bigrams

# Generate bigrams from the tokenized text
all_bigrams = [bigram for tokens in data['cleaned_text'] for bigram in bigrams(tokens)]

# Count the frequency of each bigram
bigram_freq = Counter(all_bigrams)

# Get the 20 most common bigrams
common_bigrams = bigram_freq.most_common(20)

# Split the bigrams and their counts for plotting
bigrams_labels, counts = zip(*common_bigrams)
bigrams_labels = [' '.join(bigram) for bigram in bigrams_labels]  # Join bigrams into readable format

# Define a colormap
colors = cm.viridis_r([i/20 for i in range(20)])

# Plotting the most common bigrams 
plt.figure(figsize=(12, 8))
plt.barh(bigrams_labels, counts, color=colors)
plt.gca().invert_yaxis()
plt.xlabel('Frequency')
plt.ylabel('Bigrams')
plt.title('Top 20 Most Common Bigrams')
plt.show()

# %% [markdown]
# #### Most common trigrams

# %%
from nltk import trigrams

# Generate trigrams from the tokenized text
all_trigrams = [trigram for tokens in data['cleaned_text'] for trigram in trigrams(tokens)]

# Count the frequency of each trigram
trigram_freq = Counter(all_trigrams)

# Get the 20 most common trigrams
common_trigrams = trigram_freq.most_common(20)

# Split the trigrams and their counts for plotting
trigrams_labels, counts = zip(*common_trigrams)
trigrams_labels = [' '.join(trigram) for trigram in trigrams_labels]  # Join trigrams into readable format

# Define a colormap
colors = cm.viridis_r([i/20 for i in range(20)])

# Plotting the most common trigrams 
plt.figure(figsize=(12, 8))
plt.barh(trigrams_labels, counts, color=colors)
plt.gca().invert_yaxis()
plt.xlabel('Frequency')
plt.ylabel('Trigrams')
plt.title('Top 20 Most Common Trigrams')
plt.show()

# %%
#separating the train and test datasets 
import pandas as pd

# Split the concatenated DataFrame back into 'train' and 'test'
train_split = data.iloc[:ntrain].reset_index(drop=True)
test_split = data.iloc[ntrain:ntrain+ntest].reset_index(drop=True)

# Optionally, you can print the shapes to verify
print(f"Train shape: {train_split.shape}")
print(f"Test shape: {test_split.shape}")
# Out:
# Train shape: (11849, 5)
# Test shape: (2942, 5)

# %%
train_split.head()
# Out:
#                  tweet_id                                               text  \
# 0  ID_1001136696589631488  Flash floods struck a Maryland city on Sunday,...
# 1  ID_1001136950345109504  State of emergency declared for Maryland flood...
# 2  ID_1001137334056833024  Other parts of Maryland also saw significant d...
# 3  ID_1001138374923579392  Catastrophic Flooding Slams Ellicott City, Mar...
# 4  ID_1001138377717157888  WATCH: 1 missing after flash #FLOODING devasta...
#
#                  location                                       cleaned_text  \
# 0                Maryland  [flash, flood, strike, maryland, city, sunday,...
# 1                Maryland  [state, emergency, declare, maryland, flood, v...
# 2      Baltimore Maryland  [part, maryland, also, saw, significant, damag...
# 3  Ellicott City Maryland  [catastrophic, flood, slams, ellicott, city, m...
# 4  Ellicott City Maryland  [watch, miss, flash, flooding, devastate, elli...
#
#          cleaned_location
# 0                maryland
# 1                maryland
# 2      baltimore maryland
# 3  ellicott city maryland
# 4  ellicott city maryland

# %%
test_split.head()
# Out:
#                  tweet_id                                               text  \
# 0  ID_1001154804658286592  What is happening to the infrastructure in New...
# 1  ID_1001155505459486720  SOLDER MISSING IN FLOOD.. PRAY FOR EDDISON HER...
# 2  ID_1001155756371136512  RT @TIME: Police searching for missing person ...
# 3  ID_1001159445194399744  Flash Flood Tears Through Maryland Town For Se...
# 4  ID_1001164907587538944  Ellicott City #FLOODING Pictures: Maryland Gov...
#
#   location                                       cleaned_text cleaned_location
# 0      NaN  [happen, infrastructure, new, england, isnt, g...              NaN
# 1      NaN  [solder, miss, flood, pray, eddison, hermond, ...              NaN
# 2      NaN  [time, police, search, miss, person, devastate...              NaN
# 3      NaN  [flash, flood, tear, maryland, town, second, t...              NaN
# 4      NaN  [ellicott, city, flooding, picture, maryland, ...              NaN

# %%
train_split.to_csv('cleaned_train',index=False)

# %%
test_split.to_csv('cleaned_test',index=False)
